');
# var x = new MutationObserver(function (mutations, observer) {{
#         var displ

# %%
#working with dataset
import pandas as pd

# %%
pubg=pd.read_csv('PlayerUnknowns Battlegrounds_GunInfo.csv')
df_pubg=pubg.apply(pd.to_numeric,errors='ignore')
df_pubg.head(10)
# Out:
# C:\Users\UMESH SOLANKI\AppData\Local\Temp\ipykernel_17452\3363133044.py:2: FutureWarning:
#
# errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#        name       category  ammunition  Clip capacity  volume  Na  0hurt  \
# 0      P18C         pistol        9.00             17     100   3     19
# 1     P1911         pistol        0.45              7     100   3     35
# 2       P92         pistol        9.00             15     100   3     29
# 3     R1895         pistol        7.62              7      80   1     46
# 4       AKM  Assault rifle        7.62             30      30   3     48
# 5     Groza  Assault rifle        7.62             30     500   3     48
# 6     M16A4  Assault rifle        5.56             30     500   3     41
# 7      M416  Assault rifle        5.56             30     500   3     41
# 8    SCAR-L  Assault rifle        5.56             30     500   3     41
# 9  Crossbow       Crossbow         NaN              1     500   2    105
#
#    1hurt  2hurt  3hurt  0hurthead  1hurthead  2hurthead  3hurthead
# 0   13.3   11.4   8.55       47.5      33.25       28.5     21.375
# 1   24.5   21.0  15.75       87.5      61.25       52.5     39.375
# 2   20.3   17.4  13.05       72.5      50.75       43.5     32.625
# 3   32.2   27.6  31.50      115.0      80.50       69.0     51.750
# 4   33.6   28.8  21.60      120.0      84.00       72.0     54.000
# 5   33.6   28.8  21.60      120.0      84.00       72.0     54.000
# 6   28.7   24.6  18.45      102.5      71.75       61.5     46.125
# 7   28.7   24.6  18.45      102.5      71.75       61.5     46.125
# 8   28.7   24.6  18.45      102.5      71.75       61.5     46.125
# 9   73.5   63.0  47.25      262.5     183.75      157.5    118.125

# %%
trace=go.Scatter(x=df_pubg['ammunition'],y=df_pubg['1hurthead'],
       name='category')
layout=go.Layout(title='PUBG ammo vs death',
       plot_bgcolor='rgb(230,230,230)',
       showlegend=True)
fig=go.Figure(data=[trace],layout=layout)
iplot(fig, filename='tset')
# Out:
# <div>                            <div id="9dfbeb88-bfde-4423-bb55-4015e597ad39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dfbeb88-bfde-4423-bb55-4015e597ad39")) {                    Plotly.newPlot(                        "9dfbeb88-bfde-4423-bb55-4015e597ad39",                        [{"name":"category","x":[9.0,0.45,9.0,7.62,7.62,7.62,5.56,5.56,5.56,null,9.0,0.45,9.0,0.45,12.0,12.0,12.0,0.3,7.62,7.62,9.0,7.62,5.56,5.56],"y":[33.25,61.25,50.75,80.5,84.0,84.0,71.75,71.75,71.75,183.75,40.25,66.5,61.25,54.25,346.5,393.75,393.75,231.0,126.0,147.0,61.25,96.25,105.0,77.0],"type":"scatter"}],                        {"plot_bgcolor":"rgb(230,230,230)","showlegend":true,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"typ ...
#
# var gd = document.ge

# %%
#bar plot
trace1=go.Bar(
    x=df_pubg['category'],
    y=df_pubg['1hurt'],
    name='1 damage'
    )
trace2=go.Bar(
    x=df_pubg['category'],
    y=df_pubg['3hurt'],
    name='2 damage')

# %%
data=[trace1,trace2]
layout=go.Layout(barmode='group')
fig=go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>                            <div id="1532e842-e4df-4598-9b4e-9891f8f1789a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1532e842-e4df-4598-9b4e-9891f8f1789a")) {                    Plotly.newPlot(                        "1532e842-e4df-4598-9b4e-9891f8f1789a",                        [{"name":"1 damage","x":["pistol","pistol","pistol","pistol","Assault rifle","Assault rifle","Assault rifle","Assault rifle","Assault rifle","Crossbow","Submachine gun","Submachine gun","Submachine gun","Submachine gun","Shotgun","Shotgun","Shotgun","Sniper rifle","Sniper rifle","Sniper rifle","Sniper rifle","Sniper rifle","Sniper rifle","Light machine gun"],"y":[13.3,24.5,20.3,32.2,33.6,33.6,28.7,28.7,28.7,73.5,16.1,26.6,24.5,21.7,138.6,157.5,157.5,92.4,50.4,58.8,24.5,38.5,42.0,30.8],"type":"bar"},{"name":"2 damage","x":["pistol","pistol","pistol","pistol","Assault rifle","Assault rifle","Assault rifle","Assault rifle","Assault rifle","Crossbow","Submachine gun","Submachine gun","Submachine gun","Submachine gun","Shotgun","Shotgun","Shotgun","Sniper rifle","Sniper rifle","Sniper rifle","Sniper rifle","Sniper rifle","Sniper rifle","Light machine gun"],"y":[8.55,15.75,13.05,31.5,21.6,21.6,18.45,18.45,18.45,47.25,10.35,17.1,15.75,13.95,89.1,101.25,101.25,59.4,32.4,37.8,15.75,24.75,27.0,19.8],"type":"bar"}],                        {"barmode":"group","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f" ...

# %%
#3D plotly visualization

# %%
x=df_pubg['ammunition']
y=df_pubg['volume']
z=df_pubg['1hurt']

trace1=go.Scatter3d(
    x=x,y=y,z=z,mode='markers',marker=dict(size=12,color=z,colorscale='Viridis',opacity=0.8))

data=[trace1]
layout=go.Layout(margin=dict(
    l=0,r=0,b=0,t=0   #margin in px
))

fig=go.Figure(data=data, layout=layout)
iplot(fig, filename='PlayerUnknowns Battlegrounds_GunInfo')
# Out:
# <div>                            <div id="f68ec549-7b59-449b-a5da-c9189abd70d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f68ec549-7b59-449b-a5da-c9189abd70d6")) {                    Plotly.newPlot(                        "f68ec549-7b59-449b-a5da-c9189abd70d6",                        [{"marker":{"color":[13.3,24.5,20.3,32.2,33.6,33.6,28.7,28.7,28.7,73.5,16.1,26.6,24.5,21.7,138.6,157.5,157.5,92.4,50.4,58.8,24.5,38.5,42.0,30.8],"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.8,"size":12},"mode":"markers","x":[9.0,0.45,9.0,7.62,7.62,7.62,5.56,5.56,5.56,null,9.0,0.45,9.0,0.45,12.0,12.0,12.0,0.3,7.62,7.62,9.0,7.62,5.56,5.56],"y":[100,100,100,80,30,500,500,500,500,500,500,500,500,500,500,500,500,500,500,500,500,500,500,500],"z":[13.3,24.5,20.3,32.2,33.6,33.6,28.7,28.7,28.7,73.5,16.1,26.6,24.5,21.7,138.6,157.5,157.5,92.4,50.4,58.8,24.5,38.5,42.0,30.8],"type":"scatter3d"}],                        {"margin":{"b":0,"l":0,"r":0,"t":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7 ...

# %%
#plotting on apple stock data
apple=pd.read_csv('finance-charts-apple.csv')

trace_one=go.Scatter(
    x=apple['Date'],
    y=apple['AAPL.High'],
    name="Apple High",
    line=dict(color='#17BECF'),
    opacity=0.8
)

trace_two=go.Scatter(
    x=apple['Date'],
    y=apple['AAPL.Low'],
    name="apple LOW",
    line=dict(color='#7F7F7F'),
    opacity=0.8
)
data=[trace_one, trace_two]

layout=dict(
    title='Apple Stock price- high vs Low')
fig=dict(data=data, layout=layout)
iplot(fig, filename='Apple Stock Comparision')
# Out:
# <div>                            <div id="8e2e3599-f6c7-4e3f-9ae2-cc11179d87dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e2e3599-f6c7-4e3f-9ae2-cc11179d87dd")) {                    Plotly.newPlot(                        "8e2e3599-f6c7-4e3f-9ae2-cc11179d87dd",                        [{"line":{"color":"#17BECF"},"name":"Apple High","opacity":0.8,"x":["2015-02-17","2015-02-18","2015-02-19","2015-02-20","2015-02-23","2015-02-24","2015-02-25","2015-02-26","2015-02-27","2015-03-02","2015-03-03","2015-03-04","2015-03-05","2015-03-06","2015-03-09","2015-03-10","2015-03-11","2015-03-12","2015-03-13","2015-03-16","2015-03-17","2015-03-18","2015-03-19","2015-03-20","2015-03-23","2015-03-24","2015-03-25","2015-03-26","2015-03-27","2015-03-30","2015-03-31","2015-04-01","2015-04-02","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-18","2015-05-19","2015-05-20","2015-05-21","2015-05-22","2015-05-26","2015-05-27","2015-05-28","2015-05-29","2015-06-01","2015-06-02","2015-06-03","2015-06-04","2015-06-05","2015-06-08","2015-06-09","2015-06-10","2015-06-11","2015-06-12","2015-06-15","2015-06-16","2015-06-17","2015-06-18","2015-06-19","2015-06-22","2015-06-23","2015-06-24","2015-06-25","2015-06-26","2015-06-29","2015-06-30","2015-07-01","2015-07-02","2015-07-06","2015-07-07","2015-07-08","2015-07-09","2015-07-10","2015-07-13","2015-07-14","2015-07-15","2015-07-16","2015-07-17","2015-07-20","2015-07-21","2015-07-22","2015-07-23","2015-07-24","2015-07-27","2015-07-28","2015-07-29","2015-07-30","2015-07-31","2015-08-03","2015-08-04","2015-08-05","2015-08-06","2015-08-07","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015-09-04","2015-09-08","2015-09-09","2015-09-10","2015-09-11","2015-09-14","2015-09-15","2015-09-16","2015-09-17","2015-09-18","2015-09-21","2015-09-22","2015-09-23","2015-09-24","2015-09-25","2015-09-28","2015-09-29","2015-09-30","2015-10-01","2015-10-02","2015-10-05","2015-10-06","2015-10-07","2015-10-08","2015-10-09","2015-10-12","2015-10-13","2015-10-14","2015-10-15","2015-10-16","2015-10-19","2015-10-20","2015-10-21","2015-10-22","2015-10-23","2015-10-26","2015-10-27","2015-10-28","2015-10-29","2015-10-30","2015-11-02","2015-11-03","2015-11-04","2015-11-05","2015-11-06","2015-11-09","2015-11-10","2015-11-11","2015-11-12","2015-11-13","2015-11-16","2015-11-17","2015-11-18","2015-11-19","2015-11-20","2015-11-23","2015-11-24","2015-11-25","2015-11-27","2015-11-30","2015-12-01","2015-12-02","2015-12-03","2015-12-04","2015-12-07","2015-12-08","2015-12-09","2015-12-10","2015-12-11","2015-12-14","2015-12-15","2015-12-16","2015-12-17","2015-12-18","2015-12-21","2015-12-22","2015-12-23","2015-12-24","2015-12-28","2015-12-29","2015-12-30","2015-12-31","2016-01-04","2016-01-05","2016-01-06","2016-01-07","2016-01-08","2016-01-11","2016-01-12","2016-01-13","2016-01-14","2016-01-15","2016-01-19","2016-01-20","2016-01-21","2016-01-22","2016-01-25","2016-01-26","2016-01-27","2016-01-28","2016-01-29","2016-02-01","2016-02-02","2016-02-03","2016-02-04","2016-02-05","2016-02-08","2016-02-09","2016-02-10","2016-02-11","2016-02-12","2016-02-16","2016-02-17","2016-02-18","2016-02-19","2016-02-22","2016-02-23","2016-02-24","2016-02-25","2016-02-26","2016-02-29","2016-03- ...

# %%
import plotly.figure_factory as ff

scope=['Washington']
df=pd.read_csv('minoritymajority.csv')

# %%
df_new=df[df['STNAME'].isin(scope)]

values=df_new['TOT_POP'].tolist()
fips=df_new['FIPS'].tolist()

# %%
colorscale=["#36b431", "#c26f04", "#a434e3", "#1d3059", "#9cb850", "#5eaec9", "#be6bf4", "#7f17bc",
         "#aaed24", "#8dcfe6", "#7b7e10", "#91ca4e", "#ba4c93", "#30cd5a", "#efd557", "#7e8fea",
           "#5083c9", "#6c6678", "#eac0fe", "#926eb5", "#670ac0", "#432912", "#fccc32", "#8233ee",
             "#259a27", "#fdd623", "#a1d071", "#403e3c", "#e15eed", "#4ba1a0", "#fb4b57", "#efd7d0",
               "#c76ba1", "#9c5b91", "#d5bd9b", "#820582", "#448188", "#04864f", "#fce0ac", "#7bfc69",
                 "#a83dab", "#1e556d", "#cbf84d", "#0ef476", "#6684f6", "#fc045b", "#9b8bdd", "#2abb14", 
                 "#6cb8ba", "#014e50", "#dda473", "#b727c7", "#f3713e", "#9ca83a", "#869506", "#ad7af5",
                   "#305ecd", "#e04a41", "#0a6f92", "#ee21a9", "#0386f3", "#e98d2a", "#9d1be9","#7f7f7f"]

# %%
fig=ff.create_choropleth(
    fips=fips,values=values, scope=scope,
    colorscale=colorscale,round_legend_values=True,
    simplify_county=0,
    simplify_state=0,
    county_outline={'color':'rgb(15,15,55)','width':0.5},
    state_outline={'width':0.5},
    legend_title='Population Per Country',
    title='Washington'
)

iplot(fig, filename='Cholorpleth Map Creation')
# Out:
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:358: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:775: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:331: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:848: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#
# d:\others\Python\Lib\site-packages\plotly\figure_factory\_county_choropleth.py:853: ShapelyDeprecationWarning:
#
# The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
# <div>                            <div id="f78a93c1-a1b5-4e9e-9f5e-5ff219711f71" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f78a93c1-a1b5-4e9e-9f5e-5ff219711f71")) {                    Plotly.newPlot(                        "f78a93c1-a1b5-4e9e-9f5e-5ff219711f71",                        [{"fill":"toself","fillcolor":"#36b431","hoverinfo":"none","line":{"color":"rgb(15,15,55)","width":0.5},"mode":"lines","name":"2228","x":[-117.861593,-117.853168,-117.85185,-117.849351,-117.845227,-117.829091,-117.825851,-117.819892,-117.809183,-117.804659,-117.800714,-117.797242,-117.79229699999999,-117.789967,-117.780092,-117.775983,-117.772468,-117.766922,-117.765031,-117.763651,-117.76244,-117.76